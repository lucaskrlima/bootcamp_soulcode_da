# %% [markdown]
# <a href="https://colab.research.google.com/github/lucaskrlima/bootcamp_soulcode_da/blob/main/Fundamentos_Python_01_SoulCode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**FUNDAMENTOS DE PYTHON**
#
# Escola: SoulCode Academy
#
# Bootcamp: Analista de Dados - Martech - AD2
#
# Período: Semana 4
#
# Professor: Franciane Rodrigues
#
# Aluno: Lucas Kaue

# %% [markdown]
# * Lógica de programação: é a estrutura de conceitos e regras que orientam a execução do algoritimo.
#
# * Algoritimo: é a receita, ou seja, os comandos em um passo a passo claro e lógico que conduzem as ações para a resolução de um problema ou atingir um determinado objetivo.
#
# * Programa: é a implementação do algoritimo.

# %% [markdown]
# ##**Comentários e tipo básico de dados**

# %%
print("Olá, Mundo!") # Usando aspas duplas
print('Olá, Mundo!') # Usando aspas simples

# %% [markdown]
# Tipo Básico de dados

# %% [markdown]
# ![Foto 1.png](data:image/png;base64,...)

# %% [markdown]
# ## **Variáveis**

# %%
# Escrevendo dados pessoais

print(37)      #int
print(1.67)    #float
print('Lucas') #str aspas simples
print("Lima")  #str aspas duplas
print(True)    #boleano

# %% [markdown]
# **RESUMO**
#
# *   Os **comentários** são como notas que você deixa para que você ou outra pessoa possa ler e ajuda documentar o seu código
# *   **Comando print:** é uma função de saída utilizada em várias linguagens de
# programação para exibir mensagens ou valores na tela do computador.
# *   **\n**: usado para criar quebras de linha em um texto
# *   Tipos de dados no Python mais usados são int, float, str, bool
# *   int e float: dados quantitativos
# *   str: dados categóricos

# %%
# Declarando variáveis

idade = 37
altura = 1.67
nome = 'Lucas'
sobrenome = "Lima"
filho = True

# %%
# imprimindo na tela usando comando print
print(idade)
print(altura)
print(nome)
print(sobrenome)
print(filho)

# %%
# imprime na tela usando um comando print
print(idade, altura, nome, sobrenome, filho)

# %%
# comando type serve para chegar o tipo de dado que a variavel esta declarada
type(idade)

# %%
# checando o tipo de variável usando os comandos print e typ juntos
print(type(idade))
print(type(altura))
print(type(nome))
print(type(sobrenome))
#print(type(Filho))

# %%
# armazenando string e número
nome_completo = "Lucas Lima"
numero_favorito = "8"

# %%
#checando variáveis string e número
print(type(numero_favorito))

# %% [markdown]
# **Resumo**
# *  **Variáveis** permitem salvar valores na memória usando um nome que atribuímos
# * Declaramos um nome no lado esquerdo do operador igual (“=”), e no lado direito, atribuir o valor que queremos salvar para usar mais tarde.
# * Como ler: Declaramos a variável "a" ao valor do "2" do tipo int
# * a = 2
# * Como ler: Declaramos a variável "b" ao valor do "10.953" do tipo float
# * b = 10.953
# * Como ler: A variável "a" recebe valor 2 do tipo int
# * a = 2
# * Como ler: A variável "b" recebe valor 10.953 do tipo float
# * b = 10.953
# * É possível usar os dois comandos print e type juntos
# * Atenção: Número pode ser string

# %% [markdown]
# **Regras para nomes de variáveis**
# * Deve começar com uma letra (maíuscula ou minúscula) ou subcrito(_).
# * Nunca pode começar com um número.
# * Pode conter letras maiúsculas, minúsculas, números e subscrito.
# * Não pode-se utilizar como parte do nome de uma variável:
# { ( + - * / \ ; . , ?
# * Letras maiúsculas e minúsculas são diferentes:
# casa = 4
# Casa = 4

# %% [markdown]
# ## **Conversão de variáveis**

# %%
# conversão de int para float

num_int = 10
num_float = float(num_int)

# %%
# checando conversão

print(type(num_int), type(num_float))
print(num_float)

# %%
# conversão de int para string
num_int = 10
num_string = str(num_int)

# %%
# checando conversão
print(type(num_int), type(num_string))
print(num_string)

# %%
# conversão de float para int
num_float = 10.5
num_int = int(num_float)

# %%
# checando conversão
print(type(num_float), type(num_int))
print(num_int)

# %%
# conversão float para str
num_string = str(num_float)

#checando conversão
print(type(num_float), type(num_string))
print(num_string)

# %%
# conversão de str para int
num_str = '10'
num_integer = int(num_str)

# checando conversão
print(type(num_str), type(num_integer))
print(num_integer)

# %%
# conversão de str para float
num_fl = float(num_str)

# checando conversão
print(type(num_fl), type(num_str))
print(num_fl)

# %%
# FALHA NO SISTEMA:
#Conversão de str para int ()
 num_str = '10.5'
 num_int = int(num_str)

# %%
# Conversão de str para int ()
num_str = '10.5'
num_float = float(num_str) # conversão intermediária
num_int = int(num_float)

# Checando
print(type(num_str), type(num_int))
print(num_int)

# %% [markdown]
# ## **Operadores matemáticos**

# %%
# adição
n1 = 5
n2 = 7
soma = n1 + n2
print(soma)
print('A soma é:', soma)
print(f"A soma dos números é {soma:.2f}")
print(n1 + n2)
n1+n2

# %%
# subtração
a1 = 154.587
a2 = 10.548
sub = a1 - a2

# modos de apresentação
print(sub)
print('A subtração é:', round(sub))
print(f"A subtração dos números é {sub:.2f}")
print(a1 - a2)
a1 - a2

# %%
# multiplicação

b1 = 3.57
multi = b1 * 3

# modos de apresentação
print(multi)
print('A multiplicação é:', round(multi))
print(f"A multiplicação dos números é {multi:.2f}")
print(b1 * 3)
b1 * 3

# %%
# divisão
x1 = 10
x2 = 15

div = x1 / x2

#modo de apresentação
print(div)
print('A divisão é:', round(div))
print(f"A divisão dos números é {div:.2f}")
print(x1 / x2)
x1 / x2
